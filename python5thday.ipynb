# %% [markdown]
# # Series

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame,Series

# %%
s=['a','b','c','d']
s
# Out:
# ['a', 'b', 'c', 'd']

# %%
pd.Series(s)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
snacks = ['pizza','burger','shawarma','franky','sandwitch']
snacks
# Out:
# ['pizza', 'burger', 'shawarma', 'franky', 'sandwitch']

# %%
pd.Series(snacks)
# Out:
# 0        pizza
# 1       burger
# 2     shawarma
# 3       franky
# 4    sandwitch
# dtype: object

# %%
days=['Monday','Tuesday','Wednesday','Thursday','Friday']
days
# Out:
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']

# %%
pd.Series(data=snacks,index=days)
# Out:
# Monday           pizza
# Tuesday         burger
# Wednesday     shawarma
# Thursday        franky
# Friday       sandwitch
# dtype: object

# %%
a=np.array([10,20,30,40,50])
a
# Out:
# array([10, 20, 30, 40, 50])

# %%
print(a)
# Out:
# [10 20 30 40 50]

# %%
pd.Series(a)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int32

# %%
dict={'a':10,'b':20,'c':30,'d':40}
dict
# Out:
# {'a': 10, 'b': 20, 'c': 30, 'd': 40}

# %%
pd.Series(dict)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %% [markdown]
# # Numpy

# %%
a=np.array([(1,2,3,4),(4,5,6,7)])
a
# Out:
# array([[1, 2, 3, 4],
#        [4, 5, 6, 7]])

# %%
print(a.size)
# Out:
# 8

# %%
print(a.shape)
# Out:
# (2, 4)

# %%
a= a.reshape(4,2)

# %%
print(a)
# Out:
# [[1 2]
#  [3 4]
#  [4 5]
#  [6 7]]

# %%
a=np.array([(1,2,3,4),(4,5,6,7)])

# %%
a
# Out:
# array([[1, 2, 3, 4],
#        [4, 5, 6, 7]])

# %%
a[0,2] ## Accessing values
# Out:
# 3

# %%
a=np.array([1,2,3,4])
print(a)
# Out:
# [1 2 3 4]

# %%
a.min()
# Out:
# 1

# %%
a.max()
# Out:
# 4

# %%
a.sum()
# Out:
# 10

# %%
a=np.array([(1,2,3,4),(4,5,6,7)])
a
# Out:
# array([[1, 2, 3, 4],
#        [4, 5, 6, 7]])

# %%
a.max(axis=0) # Columnwise Aggregation
# Out:
# array([4, 5, 6, 7])

# %%
a.min(axis=1)# Rowwise Aggregation
# Out:
# array([1, 4])

# %% [markdown]
# ## Duplicates

# %%
dup=DataFrame({'col1':['A','A','B','B','B'],'col2':[2,2,2,3,3]})

# %%
dup
# Out:
#   col1  col2
# 0    A     2
# 1    A     2
# 2    B     2
# 3    B     3
# 4    B     3

# %%
dup.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
dup.drop_duplicates()
# Out:
#   col1  col2
# 0    A     2
# 2    B     2
# 3    B     3

# %% [markdown]
# ## Group By

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Salaries.csv')

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
df.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
#df.mean()

# %%
df.discipline.value_counts()
# Out:
# discipline
# B    42
# A    36
# Name: count, dtype: int64

# %%
df.sex.value_counts()
# Out:
# sex
# Male      39
# Female    39
# Name: count, dtype: int64

# %%
df.[[rank]].value_counts()
# Out:
#   Cell In[55], line 1
#     df.[[rank]].value_counts()
#        ^
# SyntaxError: invalid syntax

# %%
df.salary
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
df['salary']
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
df[['salary']]
# Out:
#     salary
# 0   186960
# 1    93000
# 2   110515
# 3   131205
# 4   104800
# ..     ...
# 73  105450
# 74  104542
# 75  124312
# 76  109954
# 77  109646
#
# [78 rows x 1 columns]

# %%
df.phd.describe()
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %%
df.phd.count()
# Out:
# 78

# %%
df.phd.mean()
# Out:
# 19.705128205128204

# %%
df['rank'].value_counts()
# Out:
# rank
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: count, dtype: int64

# %%
#df.groupby('rank').mean()# Text data also present with Number

# %%
df.groupby('rank')[['service','salary','phd']].mean()# Mean as Average
# Out:
#              service         salary        phd
# rank
# AssocProf  11.307692   91786.230769  15.076923
# AsstProf    2.210526   81362.789474   5.052632
# Prof       21.413043  123624.804348  27.065217

# %%
df.salary>150000
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 73    False
# 74    False
# 75    False
# 76    False
# 77    False
# Name: salary, Length: 78, dtype: bool

# %%
df[df.salary>150000]
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 27  Prof          A   45       43    Male  155865
# 31  Prof          B   22       21    Male  155750
# 44  Prof          B   23       19  Female  151768
# 72  Prof          B   24       15  Female  161101

# %%
df[df.salary<150000]
# Out:
#          rank discipline  phd  service     sex  salary
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [69 rows x 6 columns]

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.iloc[1:4, 0:3]
# Out:
#    rank discipline  phd
# 1  Prof          A   12
# 2  Prof          A   23
# 3  Prof          A   40

# %%
df.iloc[0:10,0:3]
# Out:
#         rank discipline  phd
# 0       Prof          B   56
# 1       Prof          A   12
# 2       Prof          A   23
# 3       Prof          A   40
# 4       Prof          B   20
# 5       Prof          A   20
# 6  AssocProf          A   20
# 7       Prof          A   18
# 8       Prof          A   29
# 9       Prof          A   51

# %%
df.iloc[0:2,:]
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000

# %%
df.iloc[:,4]
# Out:
# 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4       Male
#        ...
# 73    Female
# 74    Female
# 75    Female
# 76    Female
# 77    Female
# Name: sex, Length: 78, dtype: object

# %% [markdown]
# df.iloc[[1,5],[0,3]]

# %% [markdown]
# ## Distribution plots

# %%
# To See Visualization
#!pip install matplotlib
#!pip installseaborn

# %% [markdown]
# # 1 Import Libraries

# %%
#Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2.load  Dataset

# %%
df1 = pd.read_csv('salaries.csv')

# %%
df1
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
# 3.Visualization

# %%
df.salary.describe()
# Out:
# count        78.000000
# mean     108023.782051
# std       28293.661022
# min       57800.000000
# 25%       88612.500000
# 50%      104671.000000
# 75%      126774.750000
# max      186960.000000
# Name: salary, dtype: float64

# %%
plt.hist(df1['salary'])# Histogram-Continuous Data
# Out:
# (array([ 3., 15., 12., 14.,  9., 11.,  4.,  8.,  1.,  1.]),
#  array([ 57800.,  70716.,  83632.,  96548., 109464., 122380., 135296.,
#         148212., 161128., 174044., 186960.]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df1['salary'])# Histogram with bel Curve
# Out:
# <Axes: xlabel='salary', ylabel='Density'>

# %%
sns.scatterplot(x='salary',y='phd',data=df1)
# Out:
# <Axes: xlabel='salary', ylabel='phd'>

# %%
sns.pairplot(df1)# Relationship  betw all numerical Coloumn

# %%
df1['salary'].skew()
# Out:
# 0.45210256755588096

# %%
df1['salary'].kurt()
# Out:
# -0.4017126758820546

# %%
plt.boxplot(df1["salary"],vert = True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1bee71c0170>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1bee71c0770>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1bee704c560>],
#  'medians': [<matplotlib.lines.Line2D at 0x1bee71c0c50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1bee71c0ef0>],
#  'means': []}

# %%
sns.boxplot(df1)
# Out:
# <Axes: >

# %% [markdown]
# # EDA for Sales Data

# %%
   
#Load Sales data and Find detail Analysis using Visualization
#1.Load
#2.Top,Bottom,Describe,Count values,Shape,dtype,skewness,kurosis,duplicate,Null,Drop
#3.Create Histogram,Boxplot,Scatterchart ,Pairplot 
#4.Conclution

# %% [markdown]
# # 1 Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2. Load Dataset

# %%
df=pd.read_csv('sales.csv')

# %% [markdown]
# # 3.EDA(Exploratory Data Analysis)

# %%
df.head()
# Out:
#    Order ID  Order Date Customer ID  Product ID  Units Sold Total Sales
# 0     15352   3-16-2018       E1083          30           5      ?48.25
# 1      8156   4-11-2018       E1086          63          10     ?100.00
# 2     48406   6-26-2016       E1008          21          12     ?312.00
# 3     70967  11-24-2017       E1076          40          40   ?3,880.00
# 4     70148   8-12-2016       E1047          72           9      ?81.00

# %%
df.tail()
# Out:
#         Order ID Order Date Customer ID  Product ID  Units Sold Total Sales
# 106688     80929  9-11-2015       E1069           6          80   ?1,440.00
# 106689     67468   5-1-2018       E1014          14          85     ?595.00
# 106690     75144  9-28-2017       E1004          32          49     ?882.00
# 106691     77039  8-20-2015       E1050          55          67   ?1,005.00
# 106692     27085  9-15-2016       E1071           6          66   ?1,188.00

# %%
df.shape
# Out:
# (106693, 6)

# %%
df.describe()
# Out:
#             Order ID     Product ID     Units Sold
# count  106693.000000  106693.000000  106693.000000
# mean    47588.190997      39.088000      47.056217
# std     24570.401472      22.276984      24.946671
# min      5000.000000       1.000000       1.000000
# 25%     26243.000000      20.000000      25.000000
# 50%     47645.000000      39.000000      47.000000
# 75%     68884.000000      58.000000      69.000000
# max     89998.000000      77.000000     130.000000

# %%
df['Total Sales']=df['Total Sales'].str.replace('?','').str.replace(',','').astype(float)

# %%
df['Units Sold']=pd.to_numeric(df['Units Sold'],errors='coerce')

# %%
df.isnull().sum()
# Out:
# Order ID       0
# Order Date     0
# Customer ID    0
# Product ID     0
# Units Sold     0
# Total Sales    0
# dtype: int64

# %%
df.dtypes
# Out:
# Order ID         int64
# Order Date      object
# Customer ID     object
# Product ID       int64
# Units Sold       int64
# Total Sales    float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Customer ID', 'Product ID', 'Units Sold',
#        'Total Sales'],
#       dtype='object')

# %%
sns.pairplot(df)

# %%
# coerce will introduce NA values for non numeric data in the columns
df['Units Sold']=pd.to_numeric(df['Units Sold'],errors='coerce')
df['Total Sales']=pd.to_numeric(df['Total Sales'],errors='coerce')

# %%
df.dtypes
# Out:
# Order ID         int64
# Order Date      object
# Customer ID     object
# Product ID       int64
# Units Sold       int64
# Total Sales    float64
# dtype: object

# %%
df.head()
# Out:
#    Order ID  Order Date Customer ID  Product ID  Units Sold  Total Sales
# 0     15352   3-16-2018       E1083          30           5          NaN
# 1      8156   4-11-2018       E1086          63          10          NaN
# 2     48406   6-26-2016       E1008          21          12          NaN
# 3     70967  11-24-2017       E1076          40          40          NaN
# 4     70148   8-12-2016       E1047          72           9          NaN

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df['Total Sales'].skew()
# Out:
# 5.681058924174007

# %%
plt.hist(df['Units Sold'])
# Out:
# (array([1.1727e+04, 1.6512e+04, 1.5877e+04, 1.6018e+04, 1.6025e+04,
#         1.5888e+04, 1.4623e+04, 1.0000e+01, 3.0000e+00, 1.0000e+01]),
#  array([  1. ,  13.9,  26.8,  39.7,  52.6,  65.5,  78.4,  91.3, 104.2,
#         117.1, 130. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df['Total Sales'])
# Out:
# <Axes: xlabel='Total Sales', ylabel='Density'>

# %%
sns.pairplot(df)
